# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PIL import Image
import os, glob, numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
caltech_dir = "/content/drive/MyDrive/Colab Notebooks/gender_classification/dataset/train"
categories = ["man", "woman"]
num_classes = len(categories)

image_w = 128
image_h = 128

pixels = image_h * image_w * 3

X = []
y = []

for idx, category in enumerate(categories):
    
    #one-hot 돌리기.
    label = [0 for i in range(num_classes)]
    label[idx] = 1

    image_dir = caltech_dir + "/" + category
    files = glob.glob(image_dir+"/*.jpg")
    print(category, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        X.append(data)
        y.append(label)

        if i % 700 == 0:
            print(category, " : ", f)

X = np.array(X)
y = np.array(y)
#1 0  이면 man
#0 1  이면 woman 이런식


X_train, X_test, y_train, y_test = train_test_split(X, y)
xy = (X_train, X_test, y_train, y_test)
np.save("/content/drive/MyDrive/Colab Notebooks/gender_classification/dataset/gender_data1.npy", xy)

print("ok", len(y))
# Out:
# man  파일 길이 :  967
# man  :  /content/drive/MyDrive/Colab Notebooks/gender_classification/dataset/train/man/image_1007.jpg
# man  :  /content/drive/MyDrive/Colab Notebooks/gender_classification/dataset/train/man/image_2000 (115).jpg
# woman  파일 길이 :  911
# woman  :  /content/drive/MyDrive/Colab Notebooks/gender_classification/dataset/train/woman/image_1006.jpg
# woman  :  /content/drive/MyDrive/Colab Notebooks/gender_classification/dataset/train/woman/image_931.jpg
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# ok 1878

# %%
categories = ["man", "woman"]
num_classes = len(categories)

#일반화
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %%
model = Sequential()
model.add(Conv2D(64, 3, strides= 1, padding='same', input_shape=X_train.shape[1:]))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(64, 3, strides= 1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(MaxPool2D((2,2), strides=2))

model.add(Conv2D(128, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(128, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(MaxPool2D((2, 2), strides=2))

model.add(Conv2D(256, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(256, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(256, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(MaxPool2D((2, 2), strides=2))

model.add(Conv2D(512, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(512, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(Conv2D(512, 3, strides=1, padding='same'))
model.add(BatchNormalization())
model.add(Activation(activation='relu'))
model.add(MaxPool2D((2, 2), strides=2))
model.add(MaxPool2D((2, 2), strides=2))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 64)      1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 64)      256
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 512)       1180160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 16, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              33558528
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 57,994,050
# Trainable params: 57,988,674
# Non-trainable params: 5,376
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, 
                    batch_size = 32, 
                    epochs = 100, 
                    verbose = 1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 44/44 [==============================] - 52s 403ms/step - loss: 14.2942 - accuracy: 0.4979 - val_loss: 7.9467 - val_accuracy: 0.5532
# Epoch 2/100
# 44/44 [==============================] - 16s 360ms/step - loss: 1.5276 - accuracy: 0.5149 - val_loss: 0.7114 - val_accuracy: 0.6298
# Epoch 3/100
# 44/44 [==============================] - 16s 359ms/step - loss: 1.5451 - accuracy: 0.4893 - val_loss: 1.0672 - val_accuracy: 0.4447
# Epoch 4/100
# 44/44 [==============================] - 16s 359ms/step - loss: 1.3052 - accuracy: 0.5071 - val_loss: 2.3776 - val_accuracy: 0.5638
# Epoch 5/100
# 44/44 [==============================] - 16s 359ms/step - loss: 1.3128 - accuracy: 0.5249 - val_loss: 0.9209 - val_accuracy: 0.5638
# Epoch 6/100
# 44/44 [==============================] - 16s 359ms/step - loss: 1.3244 - accuracy: 0.5263 - val_loss: 0.6751 - val_accuracy: 0.5617
# Epoch 7/100
# 44/44 [==============================] - 16s 359ms/step - loss: 1.3090 - accuracy: 0.5760 - val_loss: 0.6549 - val_accuracy: 0.6064
# Epoch 8/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.8840 - accuracy: 0.5810 - val_loss: 0.6355 - val_accuracy: 0.6404
# Epoch 9/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.7730 - accuracy: 0.6094 - val_loss: 0.6866 - val_accuracy: 0.5511
# Epoch 10/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.7454 - accuracy: 0.6442 - val_loss: 0.6492 - val_accuracy: 0.5979
# Epoch 11/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.6995 - accuracy: 0.6655 - val_loss: 0.7182 - val_accuracy: 0.5553
# Epoch 12/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.6366 - accuracy: 0.6719 - val_loss: 0.6666 - val_accuracy: 0.5766
# Epoch 13/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.6173 - accuracy: 0.6861 - val_loss: 0.6852 - val_accuracy: 0.5745
# Epoch 14/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5985 - accuracy: 0.6946 - val_loss: 0.6357 - val_accuracy: 0.6234
# Epoch 15/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5562 - accuracy: 0.7145 - val_loss: 0.6122 - val_accuracy: 0.6681
# Epoch 16/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5614 - accuracy: 0.7358 - val_loss: 0.5972 - val_accuracy: 0.6894
# Epoch 17/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5573 - accuracy: 0.7053 - val_loss: 0.6069 - val_accuracy: 0.6681
# Epoch 18/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5507 - accuracy: 0.7322 - val_loss: 0.6903 - val_accuracy: 0.5787
# Epoch 19/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5396 - accuracy: 0.7131 - val_loss: 0.5707 - val_accuracy: 0.6745
# Epoch 20/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4872 - accuracy: 0.7393 - val_loss: 0.6167 - val_accuracy: 0.6149
# Epoch 21/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5078 - accuracy: 0.7493 - val_loss: 0.5741 - val_accuracy: 0.6723
# Epoch 22/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5735 - accuracy: 0.7045 - val_loss: 0.6895 - val_accuracy: 0.4787
# Epoch 23/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5409 - accuracy: 0.7166 - val_loss: 0.5682 - val_accuracy: 0.7021
# Epoch 24/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5017 - accuracy: 0.7536 - val_loss: 0.5646 - val_accuracy: 0.7128
# Epoch 25/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5169 - accuracy: 0.7486 - val_loss: 0.5778 - val_accuracy: 0.6660
# Epoch 26/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4989 - accuracy: 0.7330 - val_loss: 0.6697 - val_accuracy: 0.6957
# Epoch 27/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5239 - accuracy: 0.7330 - val_loss: 0.5408 - val_accuracy: 0.7277
# Epoch 28/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4940 - accuracy: 0.7500 - val_loss: 0.5673 - val_accuracy: 0.7170
# Epoch 29/100
# 44/44 [==============================] - 16s 358ms/step - loss: 0.5024 - accuracy: 0.7408 - val_loss: 0.5654 - val_accuracy: 0.7021
# Epoch 30/100
# 44/44 [==============================] - 16s 358ms/step - loss: 0.4850 - accuracy: 0.7720 - val_loss: 0.6377 - val_accuracy: 0.6106
# Epoch 31/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.5018 - accuracy: 0.7415 - val_loss: 0.5770 - val_accuracy: 0.7383
# Epoch 32/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4625 - accuracy: 0.7706 - val_loss: 0.5112 - val_accuracy: 0.7511
# Epoch 33/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4761 - accuracy: 0.7628 - val_loss: 0.6914 - val_accuracy: 0.6191
# Epoch 34/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4600 - accuracy: 0.7663 - val_loss: 0.5154 - val_accuracy: 0.7404
# Epoch 35/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4540 - accuracy: 0.7536 - val_loss: 0.5084 - val_accuracy: 0.7830
# Epoch 36/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4512 - accuracy: 0.7940 - val_loss: 0.9888 - val_accuracy: 0.5809
# Epoch 37/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4382 - accuracy: 0.7763 - val_loss: 0.5449 - val_accuracy: 0.7553
# Epoch 38/100
# 44/44 [==============================] - 16s 358ms/step - loss: 0.4520 - accuracy: 0.7699 - val_loss: 0.5511 - val_accuracy: 0.7511
# Epoch 39/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.4344 - accuracy: 0.8026 - val_loss: 0.5962 - val_accuracy: 0.7723
# Epoch 40/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4303 - accuracy: 0.7969 - val_loss: 0.5767 - val_accuracy: 0.7532
# Epoch 41/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4349 - accuracy: 0.7855 - val_loss: 0.5181 - val_accuracy: 0.7255
# Epoch 42/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.4286 - accuracy: 0.7649 - val_loss: 0.5282 - val_accuracy: 0.7596
# Epoch 43/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3994 - accuracy: 0.7997 - val_loss: 0.4878 - val_accuracy: 0.7617
# Epoch 44/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3902 - accuracy: 0.8075 - val_loss: 0.4699 - val_accuracy: 0.7723
# Epoch 45/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3828 - accuracy: 0.8153 - val_loss: 0.5832 - val_accuracy: 0.7617
# Epoch 46/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.3880 - accuracy: 0.8061 - val_loss: 0.4785 - val_accuracy: 0.7915
# Epoch 47/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3887 - accuracy: 0.8111 - val_loss: 0.5245 - val_accuracy: 0.7702
# Epoch 48/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.3792 - accuracy: 0.8146 - val_loss: 0.5579 - val_accuracy: 0.7915
# Epoch 49/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3757 - accuracy: 0.8281 - val_loss: 0.4876 - val_accuracy: 0.7872
# Epoch 50/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3638 - accuracy: 0.8203 - val_loss: 0.5461 - val_accuracy: 0.7340
# Epoch 51/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3532 - accuracy: 0.8345 - val_loss: 0.5980 - val_accuracy: 0.7340
# Epoch 52/100
# 44/44 [==============================] - 16s 361ms/step - loss: 0.3316 - accuracy: 0.8388 - val_loss: 0.4855 - val_accuracy: 0.8106
# Epoch 53/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3356 - accuracy: 0.8274 - val_loss: 0.4806 - val_accuracy: 0.7745
# Epoch 54/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3572 - accuracy: 0.8224 - val_loss: 1.0835 - val_accuracy: 0.6957
# Epoch 55/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3366 - accuracy: 0.8381 - val_loss: 0.7942 - val_accuracy: 0.7340
# Epoch 56/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3610 - accuracy: 0.8111 - val_loss: 0.4861 - val_accuracy: 0.7638
# Epoch 57/100
# 44/44 [==============================] - 16s 361ms/step - loss: 0.3372 - accuracy: 0.8366 - val_loss: 0.4956 - val_accuracy: 0.7915
# Epoch 58/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3463 - accuracy: 0.8182 - val_loss: 1.2761 - val_accuracy: 0.6170
# Epoch 59/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3310 - accuracy: 0.8338 - val_loss: 0.6387 - val_accuracy: 0.7702
# Epoch 60/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.3470 - accuracy: 0.8125 - val_loss: 0.4472 - val_accuracy: 0.8085
# Epoch 61/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.3040 - accuracy: 0.8466 - val_loss: 0.4499 - val_accuracy: 0.8085
# Epoch 62/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.3272 - accuracy: 0.8452 - val_loss: 0.4664 - val_accuracy: 0.7830
# Epoch 63/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.2951 - accuracy: 0.8402 - val_loss: 0.5111 - val_accuracy: 0.7702
# Epoch 64/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.2714 - accuracy: 0.8743 - val_loss: 0.4794 - val_accuracy: 0.8319
# Epoch 65/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.3025 - accuracy: 0.8565 - val_loss: 0.4601 - val_accuracy: 0.7766
# Epoch 66/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.2892 - accuracy: 0.8615 - val_loss: 0.4222 - val_accuracy: 0.8298
# Epoch 67/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.2885 - accuracy: 0.8494 - val_loss: 0.4467 - val_accuracy: 0.8021
# Epoch 68/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.2945 - accuracy: 0.8643 - val_loss: 0.4533 - val_accuracy: 0.8043
# Epoch 69/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.3003 - accuracy: 0.8501 - val_loss: 0.4327 - val_accuracy: 0.7915
# Epoch 70/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2616 - accuracy: 0.8750 - val_loss: 0.5567 - val_accuracy: 0.7851
# Epoch 71/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2484 - accuracy: 0.8771 - val_loss: 1.6852 - val_accuracy: 0.6191
# Epoch 72/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2567 - accuracy: 0.8807 - val_loss: 0.4343 - val_accuracy: 0.7894
# Epoch 73/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2613 - accuracy: 0.8643 - val_loss: 0.6745 - val_accuracy: 0.7681
# Epoch 74/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2230 - accuracy: 0.8913 - val_loss: 0.9336 - val_accuracy: 0.6979
# Epoch 75/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.2458 - accuracy: 0.8849 - val_loss: 0.6061 - val_accuracy: 0.7936
# Epoch 76/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2572 - accuracy: 0.8722 - val_loss: 0.6190 - val_accuracy: 0.8149
# Epoch 77/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2433 - accuracy: 0.8899 - val_loss: 0.4329 - val_accuracy: 0.8191
# Epoch 78/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.2112 - accuracy: 0.8928 - val_loss: 0.4622 - val_accuracy: 0.8128
# Epoch 79/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2248 - accuracy: 0.8920 - val_loss: 0.4009 - val_accuracy: 0.8489
# Epoch 80/100
# 44/44 [==============================] - 16s 361ms/step - loss: 0.2233 - accuracy: 0.8899 - val_loss: 0.4199 - val_accuracy: 0.8277
# Epoch 81/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2158 - accuracy: 0.8942 - val_loss: 0.3782 - val_accuracy: 0.8277
# Epoch 82/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2498 - accuracy: 0.8906 - val_loss: 0.4891 - val_accuracy: 0.8085
# Epoch 83/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.1972 - accuracy: 0.9190 - val_loss: 0.6052 - val_accuracy: 0.7617
# Epoch 84/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.1842 - accuracy: 0.9041 - val_loss: 0.5136 - val_accuracy: 0.8191
# Epoch 85/100
# 44/44 [==============================] - 16s 361ms/step - loss: 0.2216 - accuracy: 0.9055 - val_loss: 0.7423 - val_accuracy: 0.7681
# Epoch 86/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2246 - accuracy: 0.9070 - val_loss: 0.4587 - val_accuracy: 0.8021
# Epoch 87/100
# 44/44 [==============================] - 16s 361ms/step - loss: 0.2398 - accuracy: 0.8835 - val_loss: 0.5044 - val_accuracy: 0.8340
# Epoch 88/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.2175 - accuracy: 0.8906 - val_loss: 0.8636 - val_accuracy: 0.7702
# Epoch 89/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.2147 - accuracy: 0.8942 - val_loss: 0.3944 - val_accuracy: 0.8617
# Epoch 90/100
# 44/44 [==============================] - 16s 361ms/step - loss: 0.1944 - accuracy: 0.9077 - val_loss: 0.8461 - val_accuracy: 0.7489
# Epoch 91/100
# 44/44 [==============================] - 16s 361ms/step - loss: 0.1790 - accuracy: 0.9162 - val_loss: 0.4360 - val_accuracy: 0.8043
# Epoch 92/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.1800 - accuracy: 0.9219 - val_loss: 0.6104 - val_accuracy: 0.8170
# Epoch 93/100
# 44/44 [==============================] - 16s 361ms/step - loss: 0.2215 - accuracy: 0.8963 - val_loss: 0.6699 - val_accuracy: 0.7979
# Epoch 94/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.1561 - accuracy: 0.9190 - val_loss: 0.5763 - val_accuracy: 0.8085
# Epoch 95/100
# 44/44 [==============================] - 16s 361ms/step - loss: 0.1529 - accuracy: 0.9212 - val_loss: 0.5495 - val_accuracy: 0.8553
# Epoch 96/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.1537 - accuracy: 0.9283 - val_loss: 0.4621 - val_accuracy: 0.8511
# Epoch 97/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.1339 - accuracy: 0.9361 - val_loss: 0.6058 - val_accuracy: 0.7957
# Epoch 98/100
# 44/44 [==============================] - 16s 360ms/step - loss: 0.1652 - accuracy: 0.9254 - val_loss: 0.5208 - val_accuracy: 0.8489
# Epoch 99/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.1385 - accuracy: 0.9354 - val_loss: 0.5299 - val_accuracy: 0.8404
# Epoch 100/100
# 44/44 [==============================] - 16s 359ms/step - loss: 0.1510 - accuracy: 0.9261 - val_loss: 0.4114 - val_accuracy: 0.8617

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['epoch', 'validation'], loc = 'upper left')
plt.show()

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label='val_set_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='train_set_oss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.show()

# %%
# predict 메서드로 테스트 세트에 대한 예측 결과 확인

CLASSES = np.array(['Man', 'Woman'])

preds = model.predict(X_test) 
preds_single = CLASSES[np.argmax(preds, axis = -1)]
actual_single = CLASSES[np.argmax(y_test, axis = -1)]

# %%
n_to_show = 10
indices = np.random.choice(range(len(X_test)), n_to_show)

fig = plt.figure(figsize = (15, 3))
fig.subplots_adjust(hspace = 0.4, wspace = 0.4)

for i, idx in enumerate(indices):
  img = X_test[idx] 
  ax = fig.add_subplot(1, n_to_show, i+1)
  ax.axis('off')
  ax.text(0.5, -0.35, 'pred = ' + str(preds_single[idx]), fontsize = 10, ha = 'center', transform = ax.transAxes)
  ax.text(0.5, -0.7, 'act = ' + str(actual_single[idx]), fontsize = 10, ha = 'center', transform = ax.transAxes)
  ax.imshow(img)
